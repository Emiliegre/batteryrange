# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import ipywidgets as widgets
from ipywidgets import interactive

# Define a function to update the plot based on the selected speed and multiplier
def update_plot(speed, multiplier):
    # Load the XLSX file based on the selected speed
    file_name = f"batteryrange_{speed}.xlsx"
    df = pd.read_excel(file_name)
    
    # DWT of the ship Kvitbjorn in tons
    dwt = 4900 

    # Create a matrix (2D array) from the DataFrame
    matrix = df.values

    # Calculate the modified matrix to find the length the ship can sail with a
    
    modified_matrix = ((multiplier/100)* dwt * speed * 1.852) / ( (8.9*10**(-3)) * matrix * 2)

    # Create a heatmap-style matrix plot using matplotlib
    plt.figure(figsize=(12, 12))
    plt.imshow(modified_matrix, cmap='coolwarm', aspect='auto')

    # Add text annotations Ato the cells in the matrix
    for i in range(len(df.index)):
        for j in range(len(df.columns)):
            plt.text(j, i, f'{modified_matrix[i, j]:.2f}', ha='center', va='center', color='white')

    # Set the x-axis ticks and labels
    x_values = np.arange(4, 4 + len(df.columns))
    plt.xticks(range(len(x_values)), x_values)

    # Set the y-axis ticks and labels to match the rows in the matrix
    y_values = np.arange( len(df.index), 0, -1)
    plt.yticks(range(len(y_values)), y_values)

    plt.colorbar()
    plt.title(f"Range of batteryship (Speed {speed} knots) - Percentage of dwt: {multiplier} %")
    plt.xlabel("Tp")
    plt.ylabel("Hs")
    plt.show()

# Create a slider widget for speed
speed_slider = widgets.IntSlider(value=5, min=5, max=15, step=1, description='Speed')

# Create a slider widget for the multiplier
multiplier_slider = widgets.FloatSlider(value=1.0, min=1.0, max=50.0, step=1.0, description='% of dwt')

# Create an interactive plot with both sliders
interactive_plot = interactive(update_plot, speed=speed_slider, multiplier=multiplier_slider)

# Display the interactive plot
output = interactive_plot.children[-1]
output.layout.height = '500px'
interactive_plot
# Out:
# interactive(children=(IntSlider(value=5, description='Speed', max=15, min=5), FloatSlider(value=1.0, descripti…

# %%
# !pip install nbconvert

# !jupyter nbconvert --to html range_matrix.ipynb
# Out:
# Requirement already satisfied: nbconvert in c:\users\emili\anaconda\lib\site-packages (6.4.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\emili\anaconda\lib\site-packages (from nbconvert) (0.5.13)
# Requirement already satisfied: defusedxml in c:\users\emili\anaconda\lib\site-packages (from nbconvert) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\emili\anaconda\lib\site-packages (from nbconvert) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\emili\anaconda\lib\site-packages (from nbconvert) (1.5.0)
# Requirement already satisfied: traitlets>=5.0 in c:\users\emili\anaconda\lib\site-packages (from nbconvert) (5.1.1)
# Requirement already satisfied: testpath in c:\users\emili\anaconda\lib\site-packages (from nbconvert) (0.5.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\emili\anaconda\lib\site-packages (from nbconvert) (4.11.1)
# Requirement already satisfied: jupyter-core in c:\users\emili\anaconda\lib\site-packages (from nbconvert) (4.9.2)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\emili\appdata\roaming\python\python39\site-packages (from nbconvert) (2.13.0)
# Requirement already satisfied: bleach in c:\users\emili\anaconda\lib\site-packages (from nbconvert) (4.1.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\emili\anaconda\lib\site-packages (from nbconvert) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\emili\appdata\roaming\python\python39\site-packages (from nbconvert) (0.4)
# Requirement already satisfied: jinja2>=2.4 in c:\users\emili\anaconda\lib\site-packages (from nbconvert) (2.11.3)
# Requirement already satisfied: nbformat>=4.4 in c:\users\emili\anaconda\lib\site-packages (from nbconvert) (5.3.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\emili\anaconda\lib\site-packages (from jinja2>=2.4->nbconvert) (2.0.1)
# Requirement already satisfied: jupyter-client>=6.1.5 in c:\users\emili\appdata\roaming\python\python39\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert) (7.4.4)
# Requirement already satisfied: nest-asyncio in c:\users\emili\appdata\roaming\python\python39\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert) (1.5.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\emili\appdata\roaming\python\python39\site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert) (2.8.2)
# Requirement already satisfied: pyzmq>=23.0 in c:\users\emili\appdata\roaming\python\python39\site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert) (24.0.1)
# Requirement already satisfied: tornado>=6.2 in c:\users\emili\appdata\roaming\python\python39\site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert) (6.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\emili\anaconda\lib\site-packages (from jupyter-core->nbconvert) (302)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\emili\anaconda\lib\site-packages (from nbformat>=4.4->nbconvert) (4.4.0)
# Requirement already satisfied: fastjsonschema in c:\users\emili\anaconda\lib\site-packages (from nbformat>=4.4->nbconvert) (2.15.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\emili\anaconda\lib\site-packages (from jsonschema>=2.6->nbformat>=4.4->nbconvert) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\emili\anaconda\lib\site-packages (from jsonschema>=2.6->nbformat>=4.4->nbconvert) (21.4.0)
# Requirement already satisfied: six>=1.5 in c:\users\emili\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert) (1.15.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\emili\anaconda\lib\site-packages (from beautifulsoup4->nbconvert) (2.3.1)
# Requirement already satisfied: packaging in c:\users\emili\anaconda\lib\site-packages (from bleach->nbconvert) (21.3)
# Requirement already satisfied: webencodings in c:\users\emili\anaconda\lib\site-packages (from bleach->nbconvert) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\emili\anaconda\lib\site-packages (from packaging->bleach->nbconvert) (3.0.4)
# [NbConvertApp] Converting notebook range_matrix.ipynb to html
# [NbConvertApp] Writing 590989 bytes to range_matrix.html
